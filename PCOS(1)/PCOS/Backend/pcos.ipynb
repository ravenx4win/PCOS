# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('PCOS.csv')

# %%
data.head()
# Out:
#     Age (yrs)  Weight (Kg)  Height(Cm)      BMI  Blood Group  \
# 0          28         44.6        152.0    19.3           15
# 1          36         65.0        161.5  #NAME?           15
# 2          33         68.8        165.0  #NAME?           11
# 3          37         65.0        148.0  #NAME?           13
# 4          25         52.0        161.0  #NAME?           11
#
#    Pulse rate(bpm)   RR (breaths/min)  Hb(g/dl)  Cycle(R/I)  \
# 0                78                22     10.48           2
# 1                74                20     11.70           2
# 2                72                18     11.80           2
# 3                72                20     12.00           2
# 4                72                18     10.00           2
#
#    Cycle length(days)  ...  Fast food (Y/N)  Reg.Exercise(Y/N)  \
# 0                   5  ...              1.0                  0
# 1                   5  ...              0.0                  0
# ...

# %%
data= data[[' Age (yrs)','Weight (Kg)','Blood Group','Hb(g/dl)','Marraige Status (Yrs)','Pregnant(Y/N)','RR (breaths/min)','RBS(mg/dl)','Weight gain(Y/N)','Skin darkening (Y/N)','Hair loss(Y/N)','Pimples(Y/N)','Endometrium (mm)','PCOS (Y/N)']]

# %%
data
# Out:
#         Age (yrs)  Weight (Kg)  Blood Group  Hb(g/dl)  Marraige Status (Yrs)  \
# 0              28         44.6           15     10.48                    7.0
# 1              36         65.0           15     11.70                   11.0
# 2              33         68.8           11     11.80                   10.0
# 3              37         65.0           13     12.00                    4.0
# 4              25         52.0           11     10.00                    1.0
# ...           ...          ...          ...       ...                    ...
# 24977          30         63.8           11     11.50                    7.0
# 24978          47         62.7           15     10.00                   30.0
# 24979          36         46.0           15     13.30                   18.0
# 24980          28         52.0           13     11.20                   11.0
# 24981          36         32.0           15     12.50                   15.0
#
# ...

# %%
data.isnull().sum()
# Out:
#  Age (yrs)                0
# Weight (Kg)               0
# Blood Group               0
# Hb(g/dl)                  0
# Marraige Status (Yrs)    44
# Pregnant(Y/N)             0
# RR (breaths/min)          0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# Skin darkening (Y/N)      0
# Hair loss(Y/N)            0
# Pimples(Y/N)              0
# Endometrium (mm)          0
# PCOS (Y/N)                0
# dtype: int64

# %%
data['Marraige Status (Yrs)']=data['Marraige Status (Yrs)'].fillna(data['Marraige Status (Yrs)'].mean())

# %%
data.isnull().sum()
# Out:
#  Age (yrs)               0
# Weight (Kg)              0
# Blood Group              0
# Hb(g/dl)                 0
# Marraige Status (Yrs)    0
# Pregnant(Y/N)            0
# RR (breaths/min)         0
# RBS(mg/dl)               0
# Weight gain(Y/N)         0
# Skin darkening (Y/N)     0
# Hair loss(Y/N)           0
# Pimples(Y/N)             0
# Endometrium (mm)         0
# PCOS (Y/N)               0
# dtype: int64

# %%
data.shape
# Out:
# (24982, 14)

# %%
data.describe()
# Out:
#           Age (yrs)   Weight (Kg)   Blood Group      Hb(g/dl)  \
# count  24982.000000  24982.000000  24982.000000  24982.000000
# mean      31.377071     59.720351     13.808022     11.169340
# std        5.393636     10.984663      1.831819      0.865947
# min       20.000000     31.000000     11.000000      8.500000
# 25%       27.000000     52.000000     13.000000     10.500000
# 50%       31.000000     60.000000     14.500000     11.000000
# 75%       35.000000     65.000000     15.000000     11.800000
# max       48.000000    108.000000     18.000000     14.800000
#
#        Marraige Status (Yrs)  Pregnant(Y/N)  RR (breaths/min)    RBS(mg/dl)  \
# count           24982.000000   24982.000000      24982.000000  24982.000000
# mean                7.676249       0.379273         19.243695     99.929894
# std                 4.788853       0.485216          1.693102     18.584016
# min                 0.000000       0.000000         16.000000     60.000000
# ...

# %%
data.nunique()
# Out:
#  Age (yrs)                29
# Weight (Kg)              117
# Blood Group                8
# Hb(g/dl)                  46
# Marraige Status (Yrs)     35
# Pregnant(Y/N)              2
# RR (breaths/min)           8
# RBS(mg/dl)                55
# Weight gain(Y/N)           2
# Skin darkening (Y/N)       2
# Hair loss(Y/N)             2
# Pimples(Y/N)               2
# Endometrium (mm)          91
# PCOS (Y/N)                 2
# dtype: int64

# %%
data.columns
# Out:
# Index([' Age (yrs)', 'Weight (Kg)', 'Blood Group', 'Hb(g/dl)',
#        'Marraige Status (Yrs)', 'Pregnant(Y/N)', 'RR (breaths/min)',
#        'RBS(mg/dl)', 'Weight gain(Y/N)', 'Skin darkening (Y/N)',
#        'Hair loss(Y/N)', 'Pimples(Y/N)', 'Endometrium (mm)', 'PCOS (Y/N)'],
#       dtype='object')

# %%
data['PCOS (Y/N)'].value_counts()
# Out:
# PCOS (Y/N)
# 0    16834
# 1     8148
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), annot=True)
plt.show()

# %%
data.plot(kind="scatter", x="PCOS (Y/N)", y="Endometrium (mm)")
# Out:
# <Axes: xlabel='PCOS (Y/N)', ylabel='Endometrium (mm)'>

# %%
sns.lineplot(data=data.head(50))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
plt.title("PCOS")
sns.barplot(x=data.head(30).index, y=data.head(30)['PCOS (Y/N)'])
plt.xlabel("BMI")
plt.ylabel("PCOS (Y/N)")
# Out:
# Text(0, 0.5, 'PCOS (Y/N)')

# %%
X = data.drop(['PCOS (Y/N)'], axis=1)
Y = data['PCOS (Y/N)']

# %%
X
# Out:
#         Age (yrs)  Weight (Kg)  Blood Group  Hb(g/dl)  Marraige Status (Yrs)  \
# 0              28         44.6           15     10.48                    7.0
# 1              36         65.0           15     11.70                   11.0
# 2              33         68.8           11     11.80                   10.0
# 3              37         65.0           13     12.00                    4.0
# 4              25         52.0           11     10.00                    1.0
# ...           ...          ...          ...       ...                    ...
# 24977          30         63.8           11     11.50                    7.0
# 24978          47         62.7           15     10.00                   30.0
# 24979          36         46.0           15     13.30                   18.0
# 24980          28         52.0           13     11.20                   11.0
# 24981          36         32.0           15     12.50                   15.0
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=70)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (19985, 13) (4997, 13) (19985,) (4997,)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy as np
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
h=model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6923 - loss: 0.9001
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7973 - loss: 0.4528
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8051 - loss: 0.4447
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8081 - loss: 0.4374
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8165 - loss: 0.4208
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8140 - loss: 0.4211
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8222 - loss: 0.4057
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 997us/step - accuracy: 0.8313 - loss: 0.3929
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8269 - loss: 0.3997
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8358 - loss: 0.3702

# %%
from sklearn.metrics import precision_score, recall_score, f1_score,accuracy_score

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svc.predict(X_test)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
acc=accuracy_score(y_test, y_pred)
print(f"Accuracy: {acc}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.7476485891534921
# Precision: 0.7864005926406417
# Recall: 0.6274325326472565
# F1 Score: 0.6299689028377372

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = KNN.predict(X_test)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')
acc=KNN.score(X_train, y_train)
print(f"Accuracy: {acc}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.9989992494370779
# Precision: 0.9966483851310177
# Recall: 0.9983664983664984
# F1 Score: 0.9975004698527343

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# Language Popularity
#python is not good with a lot of data so we shall modify our list to top 5 languages.
slices = [98, 99, 74]
labels = ['ANN \n [ 83% ]','\n KNN \n [ 99% ]', 'SVM \n [ 74% ]']
explode = [0,0.1,0] #this puts an emphasis on python

plt.pie(slices, labels = labels, explode = explode, 
        #shadow = True for asthetics to add a shadow to our plot
        shadow = True,
        #startangle = 90, rotates the original chart by 90 degress
        startangle = 95,
        wedgeprops = {'edgecolor': 'black'})

#wedgeprops is to put a boundary where the two colors meet.
#more on the matplotlib wedge documentation for more customisations.

plt.title('ACCURACY')
plt.tight_layout()
plt.show()

# %%
data
# Out:
#         Age (yrs)  Weight (Kg)  Blood Group  Hb(g/dl)  Marraige Status (Yrs)  \
# 0              28         44.6           15     10.48                    7.0
# 1              36         65.0           15     11.70                   11.0
# 2              33         68.8           11     11.80                   10.0
# 3              37         65.0           13     12.00                    4.0
# 4              25         52.0           11     10.00                    1.0
# ...           ...          ...          ...       ...                    ...
# 24977          30         63.8           11     11.50                    7.0
# 24978          47         62.7           15     10.00                   30.0
# 24979          36         46.0           15     13.30                   18.0
# 24980          28         52.0           13     11.20                   11.0
# 24981          36         32.0           15     12.50                   15.0
#
# ...

# %%
Result= KNN.predict(np.array([[28,44.6,15,10.48,7.0,0,22,92.0,0,0,0,0,8.5]]))

# %%
if Result[0]==0:
   print('Output : ', 'PCOS DISEASE')
else:
   print('Output : ', 'HEALTHY')
# Out:
# Output :  PCOS DISEASE

# %%
Result1= KNN.predict(np.array([[33,68.8,11,11.80,10.0,1,18,84.0,0,0,1,1,10.0]]))

# %%
if Result1[0]==0:
   print('Output : ', 'PCOS DISEASE')
else:
   print('Output : ', 'HEALTHY')
# Out:
# Output :  HEALTHY

# %%
import pickle
# Dump the trained KNN classifier with Pickle
KNN_filename = 'KNN.pkl'
# Open the file to save as pkl file
KNN_Model_pkl = open(KNN_filename, 'wb')
pickle.dump(KNN, KNN_Model_pkl)
# Close the pickle instances
KNN_Model_pkl.close()
